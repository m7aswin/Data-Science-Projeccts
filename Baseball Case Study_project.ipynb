# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
pd.options.display.max_columns=None

# %%
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
data.shape
# Out:
# (30, 17)

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# - No null values are present in dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# W      30 non-null int64
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# - All data types are numbers

# %% [markdown]
# Data Visualization

# %%
plt.figure(figsize=(15,12))

for col,n in zip(data.columns,range(1,len(data.columns))):
    plt.subplot(6,3,n)
    sns.boxplot(data[col])
    plt.tight_layout()

# %% [markdown]
# - There are some outliers are present in R, ERA, SHO and SV columns

# %%
plt.figure(figsize=(15,12))

for col,n in zip(data.columns,range(1,len(data.columns))):
    plt.subplot(6,3,n)
    sns.distplot(data[col])
    plt.tight_layout()

# %%
plt.figure(figsize=(15,12))
sns.heatmap(data.corr(),annot=True,cmap='Blues',fmt='.0%')

# %%
sns.pairplot(data)

# %%
xdata=data.drop(columns=['W'])
ydata=data.W

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score

# %%
std=StandardScaler()

# %%
xdata=pd.DataFrame(std.fit_transform(xdata),columns=xdata.columns)

# %%
xdata.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.697630  0.913883 -0.666234 -0.505110 -0.506955 -0.539806 -0.814629
# 1  0.154878 -0.601826  0.165971  0.248930  0.254598 -0.539806  0.172800
# 2 -0.893982  0.111449 -0.680339 -0.751623 -0.641347  2.772641 -0.320914
# 3 -0.168602 -0.690985  0.180076  0.103922  0.053010  1.300442 -0.567771
# 4  0.105866 -0.022290  1.618803  1.597501  1.531318  1.300442  0.172800
#
#          SV         E
# 0  1.671607 -0.461470
# 1  0.249879 -0.607197
# 2 -0.654856 -1.117242
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xdata,ydata,test_size=.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error

# %%
lmodel=LinearRegression()

# %%
lmodel.fit(xtrain,ytrain)
pred=lmodel.predict(xtest)
r2_score(ytest,pred)*100
# Out:
# 76.9258176375449

# %%
cross_val_score(lmodel,xdata,ydata)
# Out:
# array([ 0.71136471, -2.21099237,  0.38808753,  0.73556937,  0.5797478 ])

# %% [markdown]
# Dropping Columns having few correlation with output columns

# %%
new_x=xdata.drop(columns=['AB','H','CG','E'])

# %%
xtrain,xtest,ytrain,ytest=train_test_split(new_x,ydata,test_size=.3,random_state=42)

# %%
lmodel.fit(xtrain,ytrain)
pred=lmodel.predict(xtest)
r2_score(ytest,pred)*100
# Out:
# 81.23818164747179

# %%
#!pip install xgboost

# %%
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRFRegressor

from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
limodels=[LinearRegression(),SVR(),KNeighborsRegressor(),DecisionTreeRegressor(),RandomForestRegressor(),XGBRFRegressor()]
linames=["Linear","SVR","KNN","DecissionTree","Randomforest","XGB"]

# %%
def compilor(limodels):
    scores=[]
    mae=[]
    mse=[]
    for i in limodels:
        i.fit(xtrain,ytrain)
        scores.append(i.score(xtest,ytest))

        mae.append(mean_absolute_error(ytest,i.predict(xtest)))
        mse.append(mean_squared_error(ytest,i.predict(xtest)))
    return scores,mse,mae

# %%
accuracy,mse,mae=compilor(limodels)

# %%
for i in range(len(accuracy)):
    print("accuracy of ",linames[i], "is ",accuracy[i],"  m a e= ",mae[i]," m s e=  ",mse[i])
print("\nbest model for the problem is :", linames[np.argmax(accuracy)])
# Out:
# accuracy of  Linear is  0.8123818164747179   m a e=  3.7157419009119  m s e=   25.265915381404668
# accuracy of  SVR is  0.15704719320202465   m a e=  8.981076481343012  m s e=   113.51764464879402
# accuracy of  KNN is  0.7323762376237622   m a e=  5.222222222222224  m s e=   36.04000000000001
# accuracy of  DecissionTree is  0.5082508250825082   m a e=  6.444444444444445  m s e=   66.22222222222223
# accuracy of  Randomforest is  0.6779971947194721   m a e=  5.235555555555556  m s e=   43.36304444444443
# accuracy of  XGB is  0.7177605797197031   m a e=  5.263529459635417  m s e=   38.00824193107999
#
# best model for the problem is : Linear

# %% [markdown]
# - Best Model for this data set is LinearRegression

# %% [markdown]
# #### Best Parameter tuning for LinearRegression model
